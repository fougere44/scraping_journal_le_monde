# %% [markdown]
# # Enoncé du projet : Scraping de données de titres du journal "Le Monde"

# %% [markdown]
# ### Utiliser BeautifulSoup
#
# Les packages pour scrapper des pages HTML :
# - [BeautifulSoup4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) (``pip install bs4``)
# - [urllib](https://docs.python.org/3/library/urllib.html#module-urllib)

# %% [markdown]
# Beautiful Soup ci-dessous nous aide à gérer le html et urllib qui permet d’établir une connexion avec la page web

# %%
#import librairies

import bs4
from urllib import request
import urllib
import pandas as pd

# %% [markdown]
# L’étape suivante consiste à définir l’URL que nous voulons scraper. Cette page Web présente tous les résultats sur une seule page. Ainsi, vous devez fournir l’URL complète ici, comme dans la barre d’adresse.

# %% [markdown]
# Nous faisons ensuite la connexion à la page web avec urllib, puis nous pouvons analyser le html avec BeautifulSoup, en stockant l’objet dans la variable « page_1 ».

# %%
url = 'https://www.lemonde.fr/archives-du-monde/01-01-2018/'

req_1 = urllib.request.Request(url,headers={'User-Agent': 'Mozilla/5.0'})
html_1 = urllib.request.urlopen(req_1).read()
soup = bs4.BeautifulSoup(html_1, "lxml")

# %% [markdown]
# Nous pouvons afficher la variable "soup" à ce stade, ce qui devrait donner le html complet analysé de la page web que nous avons demandée.

# %% [markdown]
# ## Recherche d’éléments HTML
# Comme tous les résultats sont contenus dans une table, nous pouvons rechercher l’objet soup de la table en utilisant la méthode find. Nous pouvons alors trouver chaque ligne à l’intérieur de la table en utilisant la méthode find_all.

# %%
for item in page_1.find('section', { 'id' : 'river'}).findAll('h3', {'class' : 'teaser__title'}): 
    print(item, "\n-------")
# Out:
# <h3 class="teaser__title">Un réveillon « pacifié » malgré une « hausse sensible » des interpellations</h3>
# -------
# <h3 class="teaser__title">Au Gabon, Ali Bongo assure que les législatives d’avril 2018 auront bien lieu</h3>
# -------
# <h3 class="teaser__title">Petite histoire de l’intelligence artificielle à l’écran</h3>
# -------
# <h3 class="teaser__title">Les robots, superstars de la bande dessinée</h3>
# -------
# <h3 class="teaser__title">TV – « American Epic », aux origines de la musique populaire aux Etats-Unis</h3>
# -------
# <h3 class="teaser__title">Le président malien annonce un projet de loi « d’entente nationale »</h3>
# -------
# <h3 class="teaser__title">Deux policiers agressés la nuit du réveillon à Champigny-sur-Marne</h3>
# -------
# <h3 class="teaser__title">Pour 2018, le pape François veut un « avenir de paix » pour les migrants</h3>
# -------
# <h3 class="teaser__title">Etudiants : trois bonnes résolutions culturelles pour commencer 2018</h3>
# -------
# <h3 class="teaser__title">« Time’s Up » à Hollywood, un fonds pour soutenir toutes les victimes de harcèlement sexuel</h3>
# -------
# <h3 class="teaser__title">Cinq promesses d’Emmanuel Macron attendues en 2018</h3>
# -------
# <h3 class="teaser__title">Le président tchadien Idriss Déby annonce l’organisation de législatives en 2018</h3>
# -------
# <h3 class="teaser__title">Madrid évalue à 1 milliard d’euros le coût de la crise catalane</h3>
# -------
# <h3 class="teaser__title">Pour la ministre des armées en visite au Mali, « la France fait fléchir le djihadisme »</h3>
# -------
# <h3 class="teaser__title">Les développeurs stars du Web ont désormais leur agent</h3>
# -------
# <h3 class="teaser__title">« Mort au Hezbollah », « Pahlavi » : comprendre les slogans iraniens</h3>
# -------
# <h3 class="teaser__title">2018, année de la réussite</h3>
# -------
# <h3 class="teaser__title">L’Amérique de la « rust belt », au fil de l’Ohio</h3>
# -------
# <h3 class="teaser__title">Des « juges virtuels » pour désengorger les tribunaux</h3>
# -------
# <h3 class="teaser__title">Au Nigeria, 25 bûcherons tués dans une attaque de Boko Haram</h3>
# -------
# <h3 class="teaser__title">L’enseignement de la médecine se veut plus humain</h3>
# -------
# <h3 class="teaser__title">« Nos critères d’accréditation des écoles de commerce évoluent avec la société »</h3>
# -------
# <h3 class="teaser__title">Ahed Tamimi, figure familière de la résistance palestinienne</h3>
# -------
# <h3 class="teaser__title">Au moins huit morts dans la répression des marches anti-Kabila en RDC</h3>
# -------
# <h3 class="teaser__title">Macron face au piège Assad en 2018</h3>
# -------
# <h3 class="teaser__title">Le Guide suprême Ali Khamenei accuse « les ennemis de l’Iran » de fomenter des troubles</h3>
# -------
# <h3 class="teaser__title">Basket : mort de Frédéric Forte, ancien joueur et président de Limoges</h3>
# -------
# <h3 class="teaser__title">Les associations étudiantes se mobilisent pour l’environnement</h3>
# -------
# <h3 class="teaser__title">2018 : espoirs et craintes de dix-huit réfugiés à travers le monde</h3>
# -------
# <h3 class="teaser__title">Que savent vraiment faire les algorithmes ?</h3>
# -------
# <h3 class="teaser__title">Les autoentrepreneurs crèvent le plafond, mais gare aux pièges !</h3>
# -------
# <h3 class="teaser__title">Iran : la photo d’une femme devenue l’icône des protestations n’est pas liée au mouvement</h3>
# -------
# <h3 class="teaser__title">Corée du Nord : Kim Jong-un dit vouloir améliorer les relations avec le Sud et met en garde Washington</h3>
# -------
# <h3 class="teaser__title">Les célébrations du Nouvel An 2018 en images</h3>
# -------
# <h3 class="teaser__title">Marseille : un homme tué à la kalachnikov la nuit de la Saint-Sylvestre</h3>
# -------
# <h3 class="teaser__title">Douze morts dans un accident d’avion au Costa Rica</h3>
# -------
# <h3 class="teaser__title">Iran : le président Rohani sur la corde raide face aux manifestations</h3>
# -------

# %%
liste_titres_le_monde = []

for item in page_1.find('section', { 'id' : 'river'}).findAll('h3', {'class' : 'teaser__title'}) [0:] : 
        if item.get("class") :
            liste_titres_le_monde.append(item.getText())
            
            
liste_titres_le_monde [0:5]
# Out:
# ['Un réveillon «\xa0pacifié\xa0» malgré une «\xa0hausse sensible\xa0» des interpellations',
#  'Au Gabon, Ali Bongo assure que les législatives d’avril 2018 auront bien lieu',
#  'Petite histoire de l’intelligence artificielle à l’écran',
#  'Les robots, superstars de la bande dessinée',
#  'TV – «\xa0American Epic\xa0», aux origines de la musique populaire aux Etats-Unis']

# %%
for sub_heading in page_1.find_all('h3'):
    print(sub_heading.text)
# Out:
# Un réveillon « pacifié » malgré une « hausse sensible » des interpellations
# Au Gabon, Ali Bongo assure que les législatives d’avril 2018 auront bien lieu
# Petite histoire de l’intelligence artificielle à l’écran
# Les robots, superstars de la bande dessinée
# TV – « American Epic », aux origines de la musique populaire aux Etats-Unis
# Le président malien annonce un projet de loi « d’entente nationale »
# Deux policiers agressés la nuit du réveillon à Champigny-sur-Marne
# Pour 2018, le pape François veut un « avenir de paix » pour les migrants
# Etudiants : trois bonnes résolutions culturelles pour commencer 2018
# « Time’s Up » à Hollywood, un fonds pour soutenir toutes les victimes de harcèlement sexuel
# Cinq promesses d’Emmanuel Macron attendues en 2018
# Le président tchadien Idriss Déby annonce l’organisation de législatives en 2018
# Madrid évalue à 1 milliard d’euros le coût de la crise catalane
# Pour la ministre des armées en visite au Mali, « la France fait fléchir le djihadisme »
# Les développeurs stars du Web ont désormais leur agent
# « Mort au Hezbollah », « Pahlavi » : comprendre les slogans iraniens
# 2018, année de la réussite
# L’Amérique de la « rust belt », au fil de l’Ohio
# Des « juges virtuels » pour désengorger les tribunaux
# Au Nigeria, 25 bûcherons tués dans une attaque de Boko Haram
# L’enseignement de la médecine se veut plus humain
# « Nos critères d’accréditation des écoles de commerce évoluent avec la société »
# Ahed Tamimi, figure familière de la résistance palestinienne
# Au moins huit morts dans la répression des marches anti-Kabila en RDC
# Macron face au piège Assad en 2018
# Le Guide suprême Ali Khamenei accuse « les ennemis de l’Iran » de fomenter des troubles
# Basket : mort de Frédéric Forte, ancien joueur et président de Limoges
# Les associations étudiantes se mobilisent pour l’environnement
# 2018 : espoirs et craintes de dix-huit réfugiés à travers le monde
# Que savent vraiment faire les algorithmes ?
# Les autoentrepreneurs crèvent le plafond, mais gare aux pièges !
# Iran : la photo d’une femme devenue l’icône des protestations n’est pas liée au mouvement
# Corée du Nord : Kim Jong-un dit vouloir améliorer les relations avec le Sud et met en garde Washington
# Les célébrations du Nouvel An 2018 en images
# Marseille : un homme tué à la kalachnikov la nuit de la Saint-Sylvestre
# Douze morts dans un accident d’avion au Costa Rica
# Iran : le président Rohani sur la corde raide face aux manifestations

# %%
# on parse les headlines
i = 0

while i != len(liste_titres_le_monde):
    liste_titres_le_monde[i] = liste_titres_le_monde[i].replace('\n', '')
    liste_titres_le_monde[i] = liste_titres_le_monde[i].replace('«', '')
    liste_titres_le_monde[i] = liste_titres_le_monde[i].replace('»', '')
    liste_titres_le_monde[i] = liste_titres_le_monde[i].replace('\xa0', '')
    i +=1
 
    
print(liste_titres_le_monde)
# Out:
# ['Un réveillon pacifié malgré une hausse sensible des interpellations', 'Au Gabon, Ali Bongo assure que les législatives d’avril 2018 auront bien lieu', 'Petite histoire de l’intelligence artificielle à l’écran', 'Les robots, superstars de la bande dessinée', 'TV – American Epic, aux origines de la musique populaire aux Etats-Unis', 'Le président malien annonce un projet de loi d’entente nationale', 'Deux policiers agressés la nuit du réveillon àChampigny-sur-Marne', 'Pour 2018, le pape François veut un avenir de paix pour les migrants', 'Etudiants : trois bonnes résolutions culturelles pour commencer 2018', 'Time’sUp à Hollywood, un fonds pour soutenir toutes les victimes de harcèlement sexuel', 'Cinq promesses d’Emmanuel Macron attendues en 2018', 'Le président tchadien Idriss Déby annonce l’organisation de législatives en2018', 'Madrid évalue à 1milliard d’euros le coût de la crise catalane', 'Pour la ministre des armées en visite au Mali, la France fait fléchir le djihadisme', 'Les développeurs stars du Web ont désormais leur agent', 'Mort au Hezbollah, Pahlavi: comprendre les slogans iraniens', '2018, année de la réussite', 'L’Amérique de la rust belt, au fil de l’Ohio', 'Des  juges virtuels  pour désengorgerles tribunaux', 'Au Nigeria, 25bûcherons tués dans une attaque de Boko Haram', 'L’enseignement de la médecine se veut plus humain', 'Nos critères d’accréditation des écoles de commerce évoluent avec la société', 'Ahed Tamimi, figure familière de larésistance palestinienne', 'Au moins huit morts dans la répression des marches anti-Kabila en RDC', 'Macron face au piège Assad en 2018', 'Le Guide suprême Ali Khamenei accuse les ennemis de l’Iran de fomenter des troubles', 'Basket: mort de Frédéric Forte, ancien joueur et président de Limoges', 'Les associations étudiantes se mobilisent pour l’environnement', '2018: espoirs et craintes de dix-huit réfugiés àtravers le monde', 'Que savent vraiment faire les algorithmes?', 'Les autoentrepreneurs crèvent le plafond, mais gare aux pièges!', 'Iran: la photo d’une femme devenue l’icône des protestations n’est pas liée au mouvement', 'Corée du Nord: Kim Jong-un dit vouloir améliorer les relations avec le Sud et met en garde Washington', 'Les célébrations du Nouvel An 2018 en images', 'Marseille: un homme tué à la kalachnikov la nuit de la Saint-Sylvestre', 'Douze morts dans un accident d’avion au Costa Rica', 'Iran: le président Rohani sur la corde raide face aux manifestations']

# %%
# Création d'un dataframe qui regroupe tous les titres de l'url : https://www.lemonde.fr/archives-du-monde/01-01-2018/

df_titres_journaux = pd.DataFrame.from_dict( {"titres" : liste_titres_le_monde})
df_titres_journaux
# Out:
#                                                titres
# 0   Un réveillon pacifié malgré une hausse sensibl...
# 1   Au Gabon, Ali Bongo assure que les législative...
# 2   Petite histoire de l’intelligence artificielle...
# 3         Les robots, superstars de la bande dessinée
# 4   TV – American Epic, aux origines de la musique...
# 5   Le président malien annonce un projet de loi d...
# 6   Deux policiers agressés la nuit du réveillon à...
# 7   Pour 2018, le pape François veut un avenir de ...
# 8   Etudiants : trois bonnes résolutions culturell...
# 9   Time’sUp à Hollywood, un fonds pour soutenir t...
# 10  Cinq promesses d’Emmanuel Macron attendues en ...
# 11  Le président tchadien Idriss Déby annonce l’or...
# 12  Madrid évalue à 1milliard d’euros le coût de l...
# 13  Pour la ministre des armées en visite au Mali,...
# 14  Les développeurs stars du Web ont désormais le...
# 15  Mort au Hezbollah, Pahlavi: comprendre les slo...
# 16                         2018, année de la réussite
# 17       L’Amérique de la rust belt, au fil de l’Ohio
# 18  Des  juges virtuels  pour désengorgerles tribu...
# 19  Au Nigeria, 25bûcherons tués dans une attaque ...
# 20  L’enseignement de la médecine se veut plus humain
# 21  Nos critères d’accréditation des écoles de com...
# 22  Ahed Tamimi, figure familière de larésistance ...
# 23  Au moins huit morts dans la répression des mar...
# 24                 Macron face au piège Assad en 2018
# 25  Le Guide suprême Ali Khamenei accuse les ennem...
# 26  Basket: mort de Frédéric Forte, ancien joueur ...
# 27  Les associations étudiantes se mobilisent pour...
# 28  2018: espoirs et craintes de dix-huit réfugiés...
# 29         Que savent vraiment faire les algorithmes?
# 30  Les autoentrepreneurs crèvent le plafond, mais...
# 31  Iran: la photo d’une femme devenue l’icône des...
# 32  Corée du Nord: Kim Jong-un dit vouloir amélior...
# 33       Les célébrations du Nouvel An 2018 en images
# 34  Marseille: un homme tué à la kalachnikov la nu...
# 35  Douze morts dans un accident d’avion au Costa ...
# 36  Iran: le président Rohani sur la corde raide f...
